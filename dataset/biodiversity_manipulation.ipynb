# %%
import pandas as pd

# %%
df = pd.read_csv("biodiversity_dataset.csv")
df.head()
# Out:
#        gbifID                            datasetKey  \
# 0  2598658370  c6b86c40-ff71-4e5e-902c-111f400d0d56
# 1  4167812306  c6b86c40-ff71-4e5e-902c-111f400d0d56
# 2  2598661993  c6b86c40-ff71-4e5e-902c-111f400d0d56
# 3  2598664449  c6b86c40-ff71-4e5e-902c-111f400d0d56
# 4  2598666502  c6b86c40-ff71-4e5e-902c-111f400d0d56
#
#                                         occurrenceID   kingdom        phylum  \
# 0  https://indiabiodiversity.org/observation/show...  Animalia    Arthropoda
# 1  https://indiabiodiversity.org/observation/show...  Animalia    Arthropoda
# 2  https://indiabiodiversity.org/observation/show...   Plantae  Tracheophyta
# 3  https://indiabiodiversity.org/observation/show...  Animalia      Chordata
# 4  https://indiabiodiversity.org/observation/show...  Animalia    Arthropoda
#
#            class        order        family     genus                species  \
# 0        Insecta  Lepidoptera    Lycaenidae   Spalgis          Spalgis epius
# ...

# %%
df = df.drop(['datasetKey','infraspecificEpithet'],axis=1)
print(df.head())
# Out:
#        gbifID                                       occurrenceID   kingdom  \
# 0  2598658370  https://indiabiodiversity.org/observation/show...  Animalia
# 1  4167812306  https://indiabiodiversity.org/observation/show...  Animalia
# 2  2598661993  https://indiabiodiversity.org/observation/show...   Plantae
# 3  2598664449  https://indiabiodiversity.org/observation/show...  Animalia
# 4  2598666502  https://indiabiodiversity.org/observation/show...  Animalia
#
#          phylum          class        order        family     genus  \
# 0    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank  ...  \
# 0          Spalgis epius   SPECIES  ...
# ...

# %%
df = df.drop([' gbifID','occurrenceID'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
#                   verbatimScientificName  ...  \
# ...

# %%
df = df.drop(['identifiedBy','dateIdentified'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
# ...

# %%
df = df.drop(['catalogNumber','recordNumber','license','rightsHolder'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
# ...

# %%
df = df.drop(['speciesKey','basisOfRecord','institutionCode','collectionCode','recordedBy','typeStatus'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
# ...

# %%
df = df.drop(['depthAccuracy','eventDate','day','month','year','taxonKey','establishmentMeans','lastInterpreted'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
#                   verbatimScientificName  ...  \
# ...

# %%
df = df.drop(['publishingOrgKey','decimalLatitude','decimalLongitude'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
# ...

# %%
print(df.columns.values)
# Out:
# ['kingdom' 'phylum' 'class' 'order' 'family' 'genus' 'species' 'taxonRank'
#  'scientificName' 'verbatimScientificName'
#  'verbatimScientificNameAuthorship' 'countryCode' 'locality'
#  'stateProvince' 'occurrenceStatus' 'individualCount'
#  'coordinateUncertaintyInMeters' 'coordinatePrecision' 'elevation'
#  'elevationAccuracy' 'depth' 'mediaType' 'issue']

# %%
df = df.drop(['coordinateUncertaintyInMeters','coordinatePrecision','elevation','elevationAccuracy','depth','mediaType','issue'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
# ...

# %%
df = df.drop(['countryCode','locality','stateProvince','occurrenceStatus','individualCount'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
# ...

# %%
df = df.drop(['verbatimScientificNameAuthorship'],axis=1)
print(df.head())
# Out:
#     kingdom        phylum          class        order        family     genus  \
# 0  Animalia    Arthropoda        Insecta  Lepidoptera    Lycaenidae   Spalgis
# 1  Animalia    Arthropoda        Insecta      Diptera     Tipulidae       NaN
# 2   Plantae  Tracheophyta  Magnoliopsida     Myrtales    Onagraceae  Ludwigia
# 3  Animalia      Chordata       Amphibia        Anura  Microhylidae  Uperodon
# 4  Animalia    Arthropoda        Insecta  Lepidoptera   Nymphalidae    Danaus
#
#                  species taxonRank                         scientificName  \
# 0          Spalgis epius   SPECIES                          Spalgis epius
# 1                    NaN    FAMILY                              Tipulidae
# 2      Ludwigia perennis   SPECIES                   Ludwigia perennis L.
# 3  Uperodon triangularis   SPECIES  Uperodon triangularis (Günther, 1876)
# 4      Danaus chrysippus   SPECIES     Danaus chrysippus (Linnaeus, 1758)
#
#                   verbatimScientificName
# ...

# %%
df.to_csv("modified_biodiversity_dataset.csv")

# %%
df.kingdom.unique()
# Out:
# array(['Animalia', 'Plantae', 'incertae sedis', 'Fungi', 'Bacteria'],
#       dtype=object)

# %%
df.phylum.unique()
# Out:
# array(['Arthropoda', 'Tracheophyta', 'Chordata', nan, 'Mollusca',
#        'Basidiomycota', 'Platyhelminthes', 'Chlorophyta', 'Ascomycota',
#        'Cyanobacteria', 'Cnidaria', 'Bryophyta', 'Echinodermata',
#        'Anthocerotophyta'], dtype=object)

# %%
l1 = list(df.scientificName.unique())

# %%
print("Ursus maritimus" in l1)
# Out:
# False
